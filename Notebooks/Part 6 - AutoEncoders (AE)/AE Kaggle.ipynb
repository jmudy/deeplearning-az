# %% [markdown]
# # Autoencoder (Competición Kaggle)

# %% [markdown]
# ## Importar las librerías

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

# %%
from google.colab import drive
drive.mount("/content/drive")

# %cd "/content/drive/MyDrive/deeplearning-az/Notebooks/Part 6 - AutoEncoders (AE)"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/deeplearning-az/Notebooks/Part 6 - AutoEncoders (AE)

# %% [markdown]
# ## Preparar el conjunto de entrenamiento y el conjunto de testing

# %%
training_set = pd.read_csv("Kaggle/train_v2.csv")
training_set = np.array(training_set, dtype="int")
test_set = pd.read_csv("Kaggle/test_v2.csv")
test_set = np.array(test_set, dtype="int")

# %% [markdown]
# ## Obtener el número de usuarios y de películas

# %%
nb_users = int(max(max(training_set[:, 0]), max(test_set[:, 0])))
nb_movies = int(max(max(training_set[:, 1]), max(test_set[:, 1])))

# %% [markdown]
# ## Convertir los datos en un array $X_{[u,i]}$ con usuarios en $(u)$ filas y películas en $(i)$ columnas

# %%
def convert(data):
    new_data = []
    for id_user in range(1, nb_users + 1):
        id_movies = data[:, 1][data[:, 0] == id_user]
        id_ratings = data[:, 2][data[:, 0] == id_user]
        ratings = np.zeros(nb_movies)
        ratings[id_movies - 1] = id_ratings
        new_data.append(list(ratings))
    return new_data

# %%
training_set = convert(training_set)
test_set = convert(test_set)

# %% [markdown]
# ## Convertir los datos a tensores de Torch

# %%
training_set = torch.FloatTensor(training_set)
test_set = torch.FloatTensor(test_set)

# %% [markdown]
# ## Crear la arquitectura de la Red Neuronal

# %% [markdown]
# https://pytorch.org/docs/stable/generated/torch.nn.Module.html
#
# ```python
# class Model(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.conv1 = nn.Conv2d(1, 20, 5)
#         self.conv2 = nn.Conv2d(20, 20, 5)
#
#     def forward(self, x):
#         x = F.relu(self.conv1(x))
#         return F.relu(self.conv2(x))
# ```

# %%
class SAE(nn.Module):
    def __init__(self):
        super(SAE, self).__init__()
        self.fc1 = nn.Linear(nb_movies, 20)
        self.fc2 = nn.Linear(20, 10)
        self.fc3 = nn.Linear(10, 20)
        self.fc4 = nn.Linear(20, nb_movies)
        self.activation = nn.Sigmoid()
    def forward(self, x):
        x = self.activation(self.fc1(x))
        x = self.activation(self.fc2(x))
        x = self.activation(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
sae = SAE()
criterion = nn.MSELoss()
optimizer = optim.RMSprop(sae.parameters(), lr=0.01, weight_decay=0.5)

# %% [markdown]
# ## Entrenar el SAE

# %%
nb_epoch = 200
for epoch in range(1, nb_epoch + 1):
    train_loss = 0
    s = 0.0
    for id_user in range(nb_users):
        input = Variable(training_set[id_user]).unsqueeze(0)
        target = input.clone()
        if torch.sum(target.data > 0) > 0:
            output = sae.forward(input)
            target.require_grad = False
            output[target == 0] = 0
            loss = criterion(output, target)
            # la media no es sobre todas las películas, sino sobre las que realmente ha valorado
            mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
            loss.backward()
            train_loss += np.sqrt(loss.data * mean_corrector)  # sum(errors) / n_pelis_valoradas
            s += 1.0
            optimizer.step()
    print("Epoch: " + str(epoch) + ", Loss: " + str(train_loss/s))
# Out:
# Epoch: 1, Loss: tensor(1.3478)
# Epoch: 2, Loss: tensor(1.0101)
# Epoch: 3, Loss: tensor(0.9900)
# Epoch: 4, Loss: tensor(0.9834)
# Epoch: 5, Loss: tensor(0.9802)
# Epoch: 6, Loss: tensor(0.9784)
# Epoch: 7, Loss: tensor(0.9773)
# Epoch: 8, Loss: tensor(0.9766)
# Epoch: 9, Loss: tensor(0.9760)
# Epoch: 10, Loss: tensor(0.9756)
# Epoch: 11, Loss: tensor(0.9752)
# Epoch: 12, Loss: tensor(0.9751)
# Epoch: 13, Loss: tensor(0.9747)
# Epoch: 14, Loss: tensor(0.9747)
# Epoch: 15, Loss: tensor(0.9745)
# Epoch: 16, Loss: tensor(0.9744)
# Epoch: 17, Loss: tensor(0.9742)
# Epoch: 18, Loss: tensor(0.9741)
# Epoch: 19, Loss: tensor(0.9740)
# Epoch: 20, Loss: tensor(0.9739)
# Epoch: 21, Loss: tensor(0.9737)
# Epoch: 22, Loss: tensor(0.9737)
# Epoch: 23, Loss: tensor(0.9736)
# Epoch: 24, Loss: tensor(0.9732)
# Epoch: 25, Loss: tensor(0.9727)
# Epoch: 26, Loss: tensor(0.9722)
# Epoch: 27, Loss: tensor(0.9714)
# Epoch: 28, Loss: tensor(0.9707)
# Epoch: 29, Loss: tensor(0.9697)
# ...

# %% [markdown]
# ## Evaluar el conjunto de test en nuestro SAE

# %%
test_loss = 0
s = 0.0
for id_user in range(nb_users):
    input = Variable(training_set[id_user]).unsqueeze(0)
    target = Variable(test_set[id_user]).unsqueeze(0)
    if torch.sum(target.data > 0) > 0:
        output = sae.forward(input)
        target.require_grad = False
        output[target == 0] = 0
        loss = criterion(output, target)
        # la media no es sobre todas las películas, sino sobre las que realmente ha valorado
        mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
        test_loss += np.sqrt(loss.data * mean_corrector)  # sum(errors) / n_pelis_valoradas
        s += 1.0

# %%
print("Test Loss: " + str(test_loss/s))
# Out:
# Test Loss: tensor(0.9005)

# %% [markdown]
# ### Competición de Kaggle
#
# Acceso al leaderboard de la competición de [Predict Movie Ratings](https://www.kaggle.com/competitions/predict-movie-ratings/):
#
# https://www.kaggle.com/competitions/predict-movie-ratings/leaderboard
