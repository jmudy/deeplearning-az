# %% [markdown]
# # Máquinas de Boltzmann Restringidas

# %%
import numpy as np
import pandas as pd
import torch

# %%
from google.colab import drive
drive.mount("/content/drive")

# %cd "/content/drive/MyDrive/deeplearning-az/Notebooks/Part 5 - Boltzmann Machines (BM)"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/deeplearning-az/Notebooks/Part 5 - Boltzmann Machines (BM)

# %% [markdown]
# ## Importar el dataset

# %%
movies = pd.read_csv("ml-1m/movies.dat", sep="::", header=None, engine="python", encoding="latin-1")
users = pd.read_csv("ml-1m/users.dat", sep="::", header=None, engine="python", encoding="latin-1")
ratings = pd.read_csv("ml-1m/ratings.dat", sep="::", header=None, engine="python", encoding="latin-1")

# %% [markdown]
# ## Preparar el conjunto de entrenamiento y el conjunto de testing

# %%
training_set = pd.read_csv("ml-100k/u1.base", sep="\t", header=None)
training_set = np.array(training_set, dtype="int")
test_set = pd.read_csv("ml-100k/u1.test", sep="\t", header=None)
test_set = np.array(test_set, dtype="int")

# %% [markdown]
# ## Obtener el número de usuarios y de películas

# %%
nb_users = int(max(max(training_set[:, 0]), max(test_set[:, 0])))
nb_movies = int(max(max(training_set[:, 1]), max(test_set[:, 1])))

# %% [markdown]
# ## Convertir los datos en un array $X_{[u,i]}$ con usuarios en $(u)$ filas y películas en $(i)$ columnas

# %%
def convert(data):
    new_data = []
    for id_user in range(1, nb_users + 1):
        id_movies = data[:, 1][data[:, 0] == id_user]
        id_ratings = data[:, 2][data[:, 0] == id_user]
        ratings = np.zeros(nb_movies)
        ratings[id_movies - 1] = id_ratings
        new_data.append(list(ratings))
    return new_data

# %%
training_set = convert(training_set)
test_set = convert(test_set)

# %% [markdown]
# ## Convertir los datos a tensores de Torch

# %%
training_set = torch.FloatTensor(training_set)
test_set = torch.FloatTensor(test_set)

# %% [markdown]
# ## Convertir las valoraciones a valores binarios 1 (Me gusta) o 0 (No me gusta)

# %%
training_set[training_set == 0] = -1
training_set[training_set == 1] = 0
training_set[training_set == 2] = 0
training_set[training_set >= 3] = 1

# %%
test_set[test_set == 0] = -1
test_set[test_set == 1] = 0
test_set[test_set == 2] = 0
test_set[test_set >= 3] = 1

# %% [markdown]
# ## Crear la arquitectura de la Red Neuronal (Modelo Probabilistico Gráfico)

# %%
class RBM():
    def __init__(self, nv, nh):
        self.W = torch.randn(nh, nv)
        self.a = torch.randn(1, nh)
        self.b = torch.randn(1, nv)
    def sample_h(self, x):  # x = mini_batch_size x nv
        wx = torch.mm(x, self.W.t())  # mini_batch_size x nh
        activation = wx + self.a.expand_as(wx)
        p_h_given_v = torch.sigmoid(activation)
        return p_h_given_v, torch.bernoulli(p_h_given_v)
    def sample_v(self, y):  # y = mini_batch_size x nh
        wy = torch.mm(y, self.W)  # mini_batch_size x nv
        activation = wy + self.b.expand_as(wy)
        p_v_given_h = torch.sigmoid(activation)
        return p_v_given_h, torch.bernoulli(p_v_given_h)
    def train(self, v0, vk, ph0, phk):
        self.W += (torch.mm(v0.t(), ph0) - torch.mm(vk.t(), phk)).t()
        self.b += torch.sum((v0 - vk), 0)
        self.a += torch.sum((ph0 - phk), 0)

# %%
nv = len(training_set[0])
nh = 100

rbm = RBM(nv, nh)

# %% [markdown]
# ## Entrenar la RBM en base a la `distancia promedio`

# %%
nb_epoch = 10
batch_size = 100
for epoch in range(1, nb_epoch + 1):
    training_loss = 0
    s = 0.0
    for id_user in range(0, nb_users - batch_size, batch_size):
        vk = training_set[id_user:id_user + batch_size]
        v0 = training_set[id_user:id_user + batch_size]
        ph0, _ = rbm.sample_h(v0)
        for k in range(10):
            _, hk = rbm.sample_h(vk)
            _, vk = rbm.sample_v(hk)
            vk[v0 < 0] = v0[v0 < 0]
        phk,_ = rbm.sample_h(vk)
        rbm.train(v0, vk, ph0, phk)
        training_loss += torch.mean(torch.abs(v0[v0 >= 0] - vk[v0 >= 0]))  # Distancia promedio
        s += 1.0
    print("Epoch: " + str(epoch) + ", Loss: " + str(training_loss/s))
# Out:
# Epoch: 1, Loss: tensor(0.3439)
# Epoch: 2, Loss: tensor(0.2504)
# Epoch: 3, Loss: tensor(0.2514)
# Epoch: 4, Loss: tensor(0.2516)
# Epoch: 5, Loss: tensor(0.2480)
# Epoch: 6, Loss: tensor(0.2475)
# Epoch: 7, Loss: tensor(0.2477)
# Epoch: 8, Loss: tensor(0.2466)
# Epoch: 9, Loss: tensor(0.2503)
# Epoch: 10, Loss: tensor(0.2486)

# %% [markdown]
# ### Testear la RBM en base a la `distancia promedio`

# %%
testing_loss = 0
s = 0.0
for id_user in range(nb_users):
    v = training_set[id_user:id_user + 1]
    vt = test_set[id_user:id_user + 1]
    if len(vt[vt >= 0]) > 0:
        _, h = rbm.sample_h(v)
        _, v = rbm.sample_v(h)
        testing_loss += torch.mean(torch.abs(vt[vt >= 0] - v[vt >= 0]))  # Distancia promedio
        s += 1.0
        print("Testing Loss: " + str(testing_loss/s))
# Out:
# Testing Loss: tensor(0.2117)
# Testing Loss: tensor(0.2877)
# Testing Loss: tensor(0.3584)
# Testing Loss: tensor(0.3438)
# Testing Loss: tensor(0.3346)
# Testing Loss: tensor(0.3019)
# Testing Loss: tensor(0.2889)
# Testing Loss: tensor(0.2700)
# Testing Loss: tensor(0.2622)
# Testing Loss: tensor(0.2471)
# Testing Loss: tensor(0.2498)
# Testing Loss: tensor(0.2354)
# Testing Loss: tensor(0.2412)
# Testing Loss: tensor(0.2353)
# Testing Loss: tensor(0.2514)
# Testing Loss: tensor(0.2480)
# Testing Loss: tensor(0.2530)
# Testing Loss: tensor(0.2428)
# Testing Loss: tensor(0.2405)
# Testing Loss: tensor(0.2489)
# Testing Loss: tensor(0.2569)
# Testing Loss: tensor(0.2562)
# Testing Loss: tensor(0.2554)
# Testing Loss: tensor(0.2479)
# Testing Loss: tensor(0.2412)
# Testing Loss: tensor(0.2451)
# Testing Loss: tensor(0.2459)
# Testing Loss: tensor(0.2415)
# Testing Loss: tensor(0.2454)
# Testing Loss: tensor(0.2502)
# Testing Loss: tensor(0.2520)
# Testing Loss: tensor(0.2491)
# Testing Loss: tensor(0.2476)
# Testing Loss: tensor(0.2462)
# Testing Loss: tensor(0.2570)
# Testing Loss: tensor(0.2650)
# Testing Loss: tensor(0.2619)
# Testing Loss: tensor(0.2655)
# Testing Loss: tensor(0.2587)
# Testing Loss: tensor(0.2580)
# Testing Loss: tensor(0.2552)
# Testing Loss: tensor(0.2546)
# Testing Loss: tensor(0.2529)
# Testing Loss: tensor(0.2529)
# Testing Loss: tensor(0.2555)
# Testing Loss: tensor(0.2527)
# Testing Loss: tensor(0.2497)
# Testing Loss: tensor(0.2470)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2504)
# Testing Loss: tensor(0.2511)
# Testing Loss: tensor(0.2499)
# Testing Loss: tensor(0.2483)
# Testing Loss: tensor(0.2501)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2528)
# Testing Loss: tensor(0.2507)
# Testing Loss: tensor(0.2506)
# Testing Loss: tensor(0.2485)
# Testing Loss: tensor(0.2481)
# Testing Loss: tensor(0.2491)
# Testing Loss: tensor(0.2498)
# Testing Loss: tensor(0.2488)
# Testing Loss: tensor(0.2478)
# Testing Loss: tensor(0.2468)
# Testing Loss: tensor(0.2472)
# Testing Loss: tensor(0.2509)
# Testing Loss: tensor(0.2500)
# Testing Loss: tensor(0.2496)
# Testing Loss: tensor(0.2478)
# Testing Loss: tensor(0.2466)
# Testing Loss: tensor(0.2449)
# Testing Loss: tensor(0.2438)
# Testing Loss: tensor(0.2463)
# Testing Loss: tensor(0.2452)
# Testing Loss: tensor(0.2444)
# Testing Loss: tensor(0.2486)
# Testing Loss: tensor(0.2504)
# Testing Loss: tensor(0.2489)
# Testing Loss: tensor(0.2503)
# Testing Loss: tensor(0.2503)
# Testing Loss: tensor(0.2509)
# Testing Loss: tensor(0.2503)
# Testing Loss: tensor(0.2494)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2512)
# Testing Loss: tensor(0.2507)
# Testing Loss: tensor(0.2505)
# Testing Loss: tensor(0.2508)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2502)
# Testing Loss: tensor(0.2483)
# Testing Loss: tensor(0.2495)
# Testing Loss: tensor(0.2499)
# Testing Loss: tensor(0.2498)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2532)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2539)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2499)
# Testing Loss: tensor(0.2486)
# Testing Loss: tensor(0.2492)
# Testing Loss: tensor(0.2497)
# Testing Loss: tensor(0.2508)
# Testing Loss: tensor(0.2500)
# Testing Loss: tensor(0.2510)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2509)
# Testing Loss: tensor(0.2506)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2511)
# Testing Loss: tensor(0.2507)
# Testing Loss: tensor(0.2504)
# Testing Loss: tensor(0.2511)
# Testing Loss: tensor(0.2505)
# Testing Loss: tensor(0.2494)
# Testing Loss: tensor(0.2480)
# Testing Loss: tensor(0.2468)
# Testing Loss: tensor(0.2471)
# Testing Loss: tensor(0.2473)
# Testing Loss: tensor(0.2500)
# Testing Loss: tensor(0.2491)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2504)
# Testing Loss: tensor(0.2485)
# Testing Loss: tensor(0.2466)
# Testing Loss: tensor(0.2471)
# Testing Loss: tensor(0.2476)
# Testing Loss: tensor(0.2467)
# Testing Loss: tensor(0.2459)
# Testing Loss: tensor(0.2453)
# Testing Loss: tensor(0.2452)
# Testing Loss: tensor(0.2460)
# Testing Loss: tensor(0.2470)
# Testing Loss: tensor(0.2479)
# Testing Loss: tensor(0.2462)
# Testing Loss: tensor(0.2458)
# Testing Loss: tensor(0.2466)
# Testing Loss: tensor(0.2456)
# Testing Loss: tensor(0.2453)
# Testing Loss: tensor(0.2453)
# Testing Loss: tensor(0.2473)
# Testing Loss: tensor(0.2475)
# Testing Loss: tensor(0.2472)
# Testing Loss: tensor(0.2470)
# Testing Loss: tensor(0.2493)
# Testing Loss: tensor(0.2491)
# Testing Loss: tensor(0.2522)
# Testing Loss: tensor(0.2509)
# Testing Loss: tensor(0.2506)
# Testing Loss: tensor(0.2501)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2535)
# Testing Loss: tensor(0.2530)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2512)
# Testing Loss: tensor(0.2527)
# Testing Loss: tensor(0.2533)
# Testing Loss: tensor(0.2536)
# Testing Loss: tensor(0.2529)
# Testing Loss: tensor(0.2540)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2526)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2522)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2512)
# Testing Loss: tensor(0.2506)
# Testing Loss: tensor(0.2505)
# Testing Loss: tensor(0.2520)
# Testing Loss: tensor(0.2510)
# Testing Loss: tensor(0.2530)
# Testing Loss: tensor(0.2524)
# Testing Loss: tensor(0.2529)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2523)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2511)
# Testing Loss: tensor(0.2505)
# Testing Loss: tensor(0.2507)
# Testing Loss: tensor(0.2507)
# Testing Loss: tensor(0.2507)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2514)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2520)
# Testing Loss: tensor(0.2527)
# Testing Loss: tensor(0.2536)
# Testing Loss: tensor(0.2538)
# Testing Loss: tensor(0.2540)
# Testing Loss: tensor(0.2536)
# Testing Loss: tensor(0.2552)
# Testing Loss: tensor(0.2552)
# Testing Loss: tensor(0.2546)
# Testing Loss: tensor(0.2559)
# Testing Loss: tensor(0.2553)
# Testing Loss: tensor(0.2552)
# Testing Loss: tensor(0.2552)
# Testing Loss: tensor(0.2546)
# Testing Loss: tensor(0.2542)
# Testing Loss: tensor(0.2538)
# Testing Loss: tensor(0.2536)
# Testing Loss: tensor(0.2538)
# Testing Loss: tensor(0.2535)
# Testing Loss: tensor(0.2539)
# Testing Loss: tensor(0.2535)
# Testing Loss: tensor(0.2533)
# Testing Loss: tensor(0.2536)
# Testing Loss: tensor(0.2540)
# Testing Loss: tensor(0.2543)
# Testing Loss: tensor(0.2546)
# Testing Loss: tensor(0.2540)
# Testing Loss: tensor(0.2532)
# Testing Loss: tensor(0.2534)
# Testing Loss: tensor(0.2555)
# Testing Loss: tensor(0.2553)
# Testing Loss: tensor(0.2561)
# Testing Loss: tensor(0.2557)
# Testing Loss: tensor(0.2550)
# Testing Loss: tensor(0.2551)
# Testing Loss: tensor(0.2549)
# Testing Loss: tensor(0.2548)
# Testing Loss: tensor(0.2543)
# Testing Loss: tensor(0.2541)
# Testing Loss: tensor(0.2534)
# Testing Loss: tensor(0.2537)
# Testing Loss: tensor(0.2546)
# Testing Loss: tensor(0.2549)
# Testing Loss: tensor(0.2545)
# Testing Loss: tensor(0.2546)
# Testing Loss: tensor(0.2549)
# Testing Loss: tensor(0.2552)
# Testing Loss: tensor(0.2545)
# Testing Loss: tensor(0.2544)
# Testing Loss: tensor(0.2543)
# Testing Loss: tensor(0.2545)
# Testing Loss: tensor(0.2541)
# Testing Loss: tensor(0.2535)
# Testing Loss: tensor(0.2532)
# Testing Loss: tensor(0.2533)
# Testing Loss: tensor(0.2541)
# Testing Loss: tensor(0.2540)
# Testing Loss: tensor(0.2539)
# Testing Loss: tensor(0.2542)
# Testing Loss: tensor(0.2541)
# Testing Loss: tensor(0.2550)
# Testing Loss: tensor(0.2547)
# Testing Loss: tensor(0.2552)
# Testing Loss: tensor(0.2549)
# Testing Loss: tensor(0.2545)
# Testing Loss: tensor(0.2548)
# Testing Loss: tensor(0.2543)
# Testing Loss: tensor(0.2540)
# Testing Loss: tensor(0.2542)
# Testing Loss: tensor(0.2544)
# Testing Loss: tensor(0.2543)
# Testing Loss: tensor(0.2540)
# Testing Loss: tensor(0.2536)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2528)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2542)
# Testing Loss: tensor(0.2545)
# Testing Loss: tensor(0.2538)
# Testing Loss: tensor(0.2533)
# Testing Loss: tensor(0.2529)
# Testing Loss: tensor(0.2530)
# Testing Loss: tensor(0.2527)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2529)
# Testing Loss: tensor(0.2530)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2526)
# Testing Loss: tensor(0.2530)
# Testing Loss: tensor(0.2528)
# Testing Loss: tensor(0.2527)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2524)
# Testing Loss: tensor(0.2520)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2534)
# Testing Loss: tensor(0.2536)
# Testing Loss: tensor(0.2537)
# Testing Loss: tensor(0.2535)
# Testing Loss: tensor(0.2532)
# Testing Loss: tensor(0.2528)
# Testing Loss: tensor(0.2534)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2529)
# Testing Loss: tensor(0.2524)
# Testing Loss: tensor(0.2524)
# Testing Loss: tensor(0.2526)
# Testing Loss: tensor(0.2524)
# Testing Loss: tensor(0.2527)
# Testing Loss: tensor(0.2528)
# Testing Loss: tensor(0.2528)
# Testing Loss: tensor(0.2529)
# Testing Loss: tensor(0.2530)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2520)
# Testing Loss: tensor(0.2520)
# Testing Loss: tensor(0.2517)
# Testing Loss: tensor(0.2517)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2511)
# Testing Loss: tensor(0.2511)
# Testing Loss: tensor(0.2508)
# Testing Loss: tensor(0.2506)
# Testing Loss: tensor(0.2512)
# Testing Loss: tensor(0.2514)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2514)
# Testing Loss: tensor(0.2512)
# Testing Loss: tensor(0.2509)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2520)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2517)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2524)
# Testing Loss: tensor(0.2532)
# Testing Loss: tensor(0.2530)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2528)
# Testing Loss: tensor(0.2526)
# Testing Loss: tensor(0.2522)
# Testing Loss: tensor(0.2522)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2514)
# Testing Loss: tensor(0.2514)
# Testing Loss: tensor(0.2512)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2523)
# Testing Loss: tensor(0.2526)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2528)
# Testing Loss: tensor(0.2528)
# Testing Loss: tensor(0.2536)
# Testing Loss: tensor(0.2534)
# Testing Loss: tensor(0.2532)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2532)
# Testing Loss: tensor(0.2531)
# Testing Loss: tensor(0.2536)
# Testing Loss: tensor(0.2533)
# Testing Loss: tensor(0.2527)
# Testing Loss: tensor(0.2526)
# Testing Loss: tensor(0.2527)
# Testing Loss: tensor(0.2524)
# Testing Loss: tensor(0.2523)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2526)
# Testing Loss: tensor(0.2529)
# Testing Loss: tensor(0.2522)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2524)
# Testing Loss: tensor(0.2523)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2517)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2522)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2517)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2518)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2523)
# Testing Loss: tensor(0.2523)
# Testing Loss: tensor(0.2523)
# Testing Loss: tensor(0.2522)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2516)
# Testing Loss: tensor(0.2515)
# Testing Loss: tensor(0.2525)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2521)
# Testing Loss: tensor(0.2519)
# Testing Loss: tensor(0.2513)
# Testing Loss: tensor(0.2507)
# Testing Loss: tensor(0.2502)
# Testing Loss: tensor(0.2503)
# Testing Loss: tensor(0.2502)
# Testing Loss: tensor(0.2496)
# Testing Loss: tensor(0.2499)
# Testing Loss: tensor(0.2497)
# Testing Loss: tensor(0.2494)
# Testing Loss: tensor(0.2499)
# Testing Loss: tensor(0.2496)
# Testing Loss: tensor(0.2490)
# Testing Loss: tensor(0.2484)
# Testing Loss: tensor(0.2483)
# Testing Loss: tensor(0.2477)
# Testing Loss: tensor(0.2471)
# Testing Loss: tensor(0.2473)
# Testing Loss: tensor(0.2472)
# Testing Loss: tensor(0.2474)
# Testing Loss: tensor(0.2474)
# Testing Loss: tensor(0.2468)
# Testing Loss: tensor(0.2463)
# Testing Loss: tensor(0.2468)
# Testing Loss: tensor(0.2462)
# Testing Loss: tensor(0.2472)
# Testing Loss: tensor(0.2489)
# Testing Loss: tensor(0.2487)
# Testing Loss: tensor(0.2489)
# Testing Loss: tensor(0.2486)
# Testing Loss: tensor(0.2484)
# Testing Loss: tensor(0.2491)
# Testing Loss: tensor(0.2494)
# Testing Loss: tensor(0.2495)
# Testing Loss: tensor(0.2498)
# Testing Loss: tensor(0.2492)
# Testing Loss: tensor(0.2503)
# Testing Loss: tensor(0.2503)
# Testing Loss: tensor(0.2498)
# Testing Loss: tensor(0.2492)
# Testing Loss: tensor(0.2487)
# Testing Loss: tensor(0.2481)

# %%
# Comprobar como 0.25 de distancia promedio se corresponde con una tasa del 75% de éxito

u = np.random.choice([0, 1], 100000)
v = np.random.choice([0, 1], 100000)
u[:50000] = v[:50000]
sum(u==v)/float(len(u)) # -> obtendremos 0.75
np.mean(np.abs(u-v)) # -> obtendremos 0.25
# Out:
# 0.24981

# %% [markdown]
# ## Entrenar la RBM en base al `RMSE`

# %%
nb_epoch = 10
batch_size = 100
for epoch in range(1, nb_epoch + 1):
    training_loss = 0
    s = 0.0
    for id_user in range(0, nb_users - batch_size, batch_size):
        vk = training_set[id_user:id_user + batch_size]
        v0 = training_set[id_user:id_user + batch_size]
        ph0, _ = rbm.sample_h(v0)
        for k in range(10):
            _, hk = rbm.sample_h(vk)
            _, vk = rbm.sample_v(hk)
            vk[v0 < 0] = v0[v0 < 0]
        phk,_ = rbm.sample_h(vk)
        rbm.train(v0, vk, ph0, phk)
        training_loss += np.sqrt(torch.mean((v0[v0 >= 0] - vk[v0 >= 0])**2))  # RMSE
        s += 1.0
    print("Epoch: " + str(epoch) + ", Loss: " + str(training_loss/s))
# Out:
# Epoch: 1, Loss: tensor(0.4993)
# Epoch: 2, Loss: tensor(0.4958)
# Epoch: 3, Loss: tensor(0.4962)
# Epoch: 4, Loss: tensor(0.4953)
# Epoch: 5, Loss: tensor(0.4973)
# Epoch: 6, Loss: tensor(0.4986)
# Epoch: 7, Loss: tensor(0.4989)
# Epoch: 8, Loss: tensor(0.4977)
# Epoch: 9, Loss: tensor(0.4973)
# Epoch: 10, Loss: tensor(0.4997)

# %% [markdown]
# ### Testear la RBM en base al `RMSE`

# %%
testing_loss = 0
s = 0.0
for id_user in range(nb_users):
    v = training_set[id_user:id_user + 1]
    vt = test_set[id_user:id_user + 1]
    if len(vt[vt >= 0]) > 0:
        _, h = rbm.sample_h(v)
        _, v = rbm.sample_v(h)
        testing_loss += np.sqrt(torch.mean((vt[vt >= 0] - v[vt >= 0])**2))  # RMSE
        s += 1.0
        print("Testing Loss: " + str(testing_loss/s))
# Out:
# Testing Loss: tensor(0.4680)
# Testing Loss: tensor(0.4723)
# Testing Loss: tensor(0.5595)
# Testing Loss: tensor(0.5314)
# Testing Loss: tensor(0.5561)
# Testing Loss: tensor(0.5338)
# Testing Loss: tensor(0.5214)
# Testing Loss: tensor(0.5131)
# Testing Loss: tensor(0.5058)
# Testing Loss: tensor(0.4901)
# Testing Loss: tensor(0.4977)
# Testing Loss: tensor(0.4794)
# Testing Loss: tensor(0.4849)
# Testing Loss: tensor(0.4802)
# Testing Loss: tensor(0.4942)
# Testing Loss: tensor(0.4901)
# Testing Loss: tensor(0.5005)
# Testing Loss: tensor(0.4938)
# Testing Loss: tensor(0.4913)
# Testing Loss: tensor(0.5005)
# Testing Loss: tensor(0.5051)
# Testing Loss: tensor(0.5060)
# Testing Loss: tensor(0.5013)
# Testing Loss: tensor(0.4943)
# Testing Loss: tensor(0.4892)
# Testing Loss: tensor(0.4912)
# Testing Loss: tensor(0.4922)
# Testing Loss: tensor(0.4925)
# Testing Loss: tensor(0.4960)
# Testing Loss: tensor(0.4987)
# Testing Loss: tensor(0.5045)
# Testing Loss: tensor(0.5031)
# Testing Loss: tensor(0.5014)
# Testing Loss: tensor(0.4959)
# Testing Loss: tensor(0.4993)
# Testing Loss: tensor(0.5021)
# Testing Loss: tensor(0.4971)
# Testing Loss: tensor(0.4995)
# Testing Loss: tensor(0.4952)
# Testing Loss: tensor(0.4967)
# Testing Loss: tensor(0.4938)
# Testing Loss: tensor(0.4938)
# Testing Loss: tensor(0.4927)
# Testing Loss: tensor(0.4923)
# Testing Loss: tensor(0.4928)
# Testing Loss: tensor(0.4929)
# Testing Loss: tensor(0.4925)
# Testing Loss: tensor(0.4903)
# Testing Loss: tensor(0.4941)
# Testing Loss: tensor(0.4927)
# Testing Loss: tensor(0.4905)
# Testing Loss: tensor(0.4870)
# Testing Loss: tensor(0.4855)
# Testing Loss: tensor(0.4848)
# Testing Loss: tensor(0.4837)
# Testing Loss: tensor(0.4844)
# Testing Loss: tensor(0.4860)
# Testing Loss: tensor(0.4832)
# Testing Loss: tensor(0.4832)
# Testing Loss: tensor(0.4808)
# Testing Loss: tensor(0.4806)
# Testing Loss: tensor(0.4812)
# Testing Loss: tensor(0.4824)
# Testing Loss: tensor(0.4818)
# Testing Loss: tensor(0.4811)
# Testing Loss: tensor(0.4775)
# Testing Loss: tensor(0.4789)
# Testing Loss: tensor(0.4801)
# Testing Loss: tensor(0.4787)
# Testing Loss: tensor(0.4781)
# Testing Loss: tensor(0.4763)
# Testing Loss: tensor(0.4752)
# Testing Loss: tensor(0.4729)
# Testing Loss: tensor(0.4710)
# Testing Loss: tensor(0.4737)
# Testing Loss: tensor(0.4736)
# Testing Loss: tensor(0.4706)
# Testing Loss: tensor(0.4715)
# Testing Loss: tensor(0.4734)
# Testing Loss: tensor(0.4731)
# Testing Loss: tensor(0.4730)
# Testing Loss: tensor(0.4738)
# Testing Loss: tensor(0.4756)
# Testing Loss: tensor(0.4747)
# Testing Loss: tensor(0.4743)
# Testing Loss: tensor(0.4746)
# Testing Loss: tensor(0.4742)
# Testing Loss: tensor(0.4760)
# Testing Loss: tensor(0.4748)
# Testing Loss: tensor(0.4738)
# Testing Loss: tensor(0.4725)
# Testing Loss: tensor(0.4730)
# Testing Loss: tensor(0.4744)
# Testing Loss: tensor(0.4746)
# Testing Loss: tensor(0.4747)
# Testing Loss: tensor(0.4732)
# Testing Loss: tensor(0.4722)
# Testing Loss: tensor(0.4735)
# Testing Loss: tensor(0.4740)
# Testing Loss: tensor(0.4746)
# Testing Loss: tensor(0.4754)
# Testing Loss: tensor(0.4764)
# Testing Loss: tensor(0.4744)
# Testing Loss: tensor(0.4768)
# Testing Loss: tensor(0.4758)
# Testing Loss: tensor(0.4749)
# Testing Loss: tensor(0.4748)
# Testing Loss: tensor(0.4751)
# Testing Loss: tensor(0.4756)
# Testing Loss: tensor(0.4766)
# Testing Loss: tensor(0.4781)
# Testing Loss: tensor(0.4792)
# Testing Loss: tensor(0.4809)
# Testing Loss: tensor(0.4800)
# Testing Loss: tensor(0.4804)
# Testing Loss: tensor(0.4811)
# Testing Loss: tensor(0.4811)
# Testing Loss: tensor(0.4802)
# Testing Loss: tensor(0.4798)
# Testing Loss: tensor(0.4816)
# Testing Loss: tensor(0.4818)
# Testing Loss: tensor(0.4820)
# Testing Loss: tensor(0.4814)
# Testing Loss: tensor(0.4811)
# Testing Loss: tensor(0.4816)
# Testing Loss: tensor(0.4819)
# Testing Loss: tensor(0.4832)
# Testing Loss: tensor(0.4829)
# Testing Loss: tensor(0.4844)
# Testing Loss: tensor(0.4842)
# Testing Loss: tensor(0.4849)
# Testing Loss: tensor(0.4812)
# Testing Loss: tensor(0.4813)
# Testing Loss: tensor(0.4813)
# Testing Loss: tensor(0.4821)
# Testing Loss: tensor(0.4819)
# Testing Loss: tensor(0.4824)
# Testing Loss: tensor(0.4814)
# Testing Loss: tensor(0.4821)
# Testing Loss: tensor(0.4830)
# Testing Loss: tensor(0.4837)
# Testing Loss: tensor(0.4822)
# Testing Loss: tensor(0.4833)
# Testing Loss: tensor(0.4828)
# Testing Loss: tensor(0.4835)
# Testing Loss: tensor(0.4802)
# Testing Loss: tensor(0.4806)
# Testing Loss: tensor(0.4806)
# Testing Loss: tensor(0.4823)
# Testing Loss: tensor(0.4815)
# Testing Loss: tensor(0.4815)
# Testing Loss: tensor(0.4819)
# Testing Loss: tensor(0.4834)
# Testing Loss: tensor(0.4832)
# Testing Loss: tensor(0.4849)
# Testing Loss: tensor(0.4838)
# Testing Loss: tensor(0.4834)
# Testing Loss: tensor(0.4826)
# Testing Loss: tensor(0.4831)
# Testing Loss: tensor(0.4832)
# Testing Loss: tensor(0.4847)
# Testing Loss: tensor(0.4850)
# Testing Loss: tensor(0.4820)
# Testing Loss: tensor(0.4820)
# Testing Loss: tensor(0.4821)
# Testing Loss: tensor(0.4819)
# Testing Loss: tensor(0.4830)
# Testing Loss: tensor(0.4832)
# Testing Loss: tensor(0.4831)
# Testing Loss: tensor(0.4825)
# Testing Loss: tensor(0.4797)
# Testing Loss: tensor(0.4793)
# Testing Loss: tensor(0.4785)
# Testing Loss: tensor(0.4792)
# Testing Loss: tensor(0.4786)
# Testing Loss: tensor(0.4776)
# Testing Loss: tensor(0.4775)
# Testing Loss: tensor(0.4771)
# Testing Loss: tensor(0.4776)
# Testing Loss: tensor(0.4770)
# Testing Loss: tensor(0.4787)
# Testing Loss: tensor(0.4786)
# Testing Loss: tensor(0.4796)
# Testing Loss: tensor(0.4796)
# Testing Loss: tensor(0.4789)
# Testing Loss: tensor(0.4792)
# Testing Loss: tensor(0.4783)
# Testing Loss: tensor(0.4780)
# Testing Loss: tensor(0.4774)
# Testing Loss: tensor(0.4780)
# Testing Loss: tensor(0.4780)
# Testing Loss: tensor(0.4779)
# Testing Loss: tensor(0.4784)
# Testing Loss: tensor(0.4788)
# Testing Loss: tensor(0.4791)
# Testing Loss: tensor(0.4787)
# Testing Loss: tensor(0.4787)
# Testing Loss: tensor(0.4787)
# Testing Loss: tensor(0.4792)
# Testing Loss: tensor(0.4793)
# Testing Loss: tensor(0.4801)
# Testing Loss: tensor(0.4809)
# Testing Loss: tensor(0.4810)
# Testing Loss: tensor(0.4817)
# Testing Loss: tensor(0.4818)
# Testing Loss: tensor(0.4830)
# Testing Loss: tensor(0.4829)
# Testing Loss: tensor(0.4828)
# Testing Loss: tensor(0.4840)
# Testing Loss: tensor(0.4836)
# Testing Loss: tensor(0.4840)
# Testing Loss: tensor(0.4834)
# Testing Loss: tensor(0.4828)
# Testing Loss: tensor(0.4823)
# Testing Loss: tensor(0.4825)
# Testing Loss: tensor(0.4826)
# Testing Loss: tensor(0.4835)
# Testing Loss: tensor(0.4827)
# Testing Loss: tensor(0.4834)
# Testing Loss: tensor(0.4826)
# Testing Loss: tensor(0.4823)
# Testing Loss: tensor(0.4828)
# Testing Loss: tensor(0.4835)
# Testing Loss: tensor(0.4837)
# Testing Loss: tensor(0.4844)
# Testing Loss: tensor(0.4837)
# Testing Loss: tensor(0.4835)
# Testing Loss: tensor(0.4837)
# Testing Loss: tensor(0.4852)
# Testing Loss: tensor(0.4853)
# Testing Loss: tensor(0.4845)
# Testing Loss: tensor(0.4843)
# Testing Loss: tensor(0.4834)
# Testing Loss: tensor(0.4835)
# Testing Loss: tensor(0.4833)
# Testing Loss: tensor(0.4836)
# Testing Loss: tensor(0.4828)
# Testing Loss: tensor(0.4837)
# Testing Loss: tensor(0.4834)
# Testing Loss: tensor(0.4828)
# Testing Loss: tensor(0.4829)
# Testing Loss: tensor(0.4833)
# Testing Loss: tensor(0.4832)
# Testing Loss: tensor(0.4834)
# Testing Loss: tensor(0.4841)
# Testing Loss: tensor(0.4846)
# Testing Loss: tensor(0.4847)
# Testing Loss: tensor(0.4846)
# Testing Loss: tensor(0.4842)
# Testing Loss: tensor(0.4843)
# Testing Loss: tensor(0.4838)
# Testing Loss: tensor(0.4818)
# Testing Loss: tensor(0.4810)
# Testing Loss: tensor(0.4811)
# Testing Loss: tensor(0.4821)
# Testing Loss: tensor(0.4823)
# Testing Loss: tensor(0.4825)
# Testing Loss: tensor(0.4833)
# Testing Loss: tensor(0.4836)
# Testing Loss: tensor(0.4833)
# Testing Loss: tensor(0.4831)
# Testing Loss: tensor(0.4833)
# Testing Loss: tensor(0.4829)
# Testing Loss: tensor(0.4825)
# Testing Loss: tensor(0.4826)
# Testing Loss: tensor(0.4822)
# Testing Loss: tensor(0.4820)
# Testing Loss: tensor(0.4823)
# Testing Loss: tensor(0.4825)
# Testing Loss: tensor(0.4824)
# Testing Loss: tensor(0.4821)
# Testing Loss: tensor(0.4822)
# Testing Loss: tensor(0.4816)
# Testing Loss: tensor(0.4816)
# Testing Loss: tensor(0.4814)
# Testing Loss: tensor(0.4815)
# Testing Loss: tensor(0.4815)
# Testing Loss: tensor(0.4808)
# Testing Loss: tensor(0.4811)
# Testing Loss: tensor(0.4812)
# Testing Loss: tensor(0.4822)
# Testing Loss: tensor(0.4815)
# Testing Loss: tensor(0.4814)
# Testing Loss: tensor(0.4808)
# Testing Loss: tensor(0.4804)
# Testing Loss: tensor(0.4806)
# Testing Loss: tensor(0.4804)
# Testing Loss: tensor(0.4806)
# Testing Loss: tensor(0.4808)
# Testing Loss: tensor(0.4811)
# Testing Loss: tensor(0.4815)
# Testing Loss: tensor(0.4812)
# Testing Loss: tensor(0.4816)
# Testing Loss: tensor(0.4817)
# Testing Loss: tensor(0.4819)
# Testing Loss: tensor(0.4817)
# Testing Loss: tensor(0.4818)
# Testing Loss: tensor(0.4815)
# Testing Loss: tensor(0.4816)
# Testing Loss: tensor(0.4817)
# Testing Loss: tensor(0.4817)
# Testing Loss: tensor(0.4827)
# Testing Loss: tensor(0.4829)
# Testing Loss: tensor(0.4823)
# Testing Loss: tensor(0.4825)
# Testing Loss: tensor(0.4823)
# Testing Loss: tensor(0.4817)
# Testing Loss: tensor(0.4812)
# Testing Loss: tensor(0.4812)
# Testing Loss: tensor(0.4812)
# Testing Loss: tensor(0.4811)
# Testing Loss: tensor(0.4807)
# Testing Loss: tensor(0.4808)
# Testing Loss: tensor(0.4810)
# Testing Loss: tensor(0.4807)
# Testing Loss: tensor(0.4808)
# Testing Loss: tensor(0.4803)
# Testing Loss: tensor(0.4803)
# Testing Loss: tensor(0.4800)
# Testing Loss: tensor(0.4802)
# Testing Loss: tensor(0.4797)
# Testing Loss: tensor(0.4791)
# Testing Loss: tensor(0.4790)
# Testing Loss: tensor(0.4784)
# Testing Loss: tensor(0.4786)
# Testing Loss: tensor(0.4785)
# Testing Loss: tensor(0.4787)
# Testing Loss: tensor(0.4788)
# Testing Loss: tensor(0.4786)
# Testing Loss: tensor(0.4784)
# Testing Loss: tensor(0.4781)
# Testing Loss: tensor(0.4781)
# Testing Loss: tensor(0.4784)
# Testing Loss: tensor(0.4784)
# Testing Loss: tensor(0.4784)
# Testing Loss: tensor(0.4788)
# Testing Loss: tensor(0.4790)
# Testing Loss: tensor(0.4786)
# Testing Loss: tensor(0.4785)
# Testing Loss: tensor(0.4785)
# Testing Loss: tensor(0.4785)
# Testing Loss: tensor(0.4785)
# Testing Loss: tensor(0.4785)
# Testing Loss: tensor(0.4784)
# Testing Loss: tensor(0.4785)
# Testing Loss: tensor(0.4786)
# Testing Loss: tensor(0.4788)
# Testing Loss: tensor(0.4791)
# Testing Loss: tensor(0.4800)
# Testing Loss: tensor(0.4793)
# Testing Loss: tensor(0.4795)
# Testing Loss: tensor(0.4793)
# Testing Loss: tensor(0.4793)
# Testing Loss: tensor(0.4792)
# Testing Loss: tensor(0.4794)
# Testing Loss: tensor(0.4794)
# Testing Loss: tensor(0.4795)
# Testing Loss: tensor(0.4799)
# Testing Loss: tensor(0.4799)
# Testing Loss: tensor(0.4790)
# Testing Loss: tensor(0.4789)
# Testing Loss: tensor(0.4794)
# Testing Loss: tensor(0.4797)
# Testing Loss: tensor(0.4783)
# Testing Loss: tensor(0.4785)
# Testing Loss: tensor(0.4789)
# Testing Loss: tensor(0.4791)
# Testing Loss: tensor(0.4793)
# Testing Loss: tensor(0.4780)
# Testing Loss: tensor(0.4779)
# Testing Loss: tensor(0.4774)
# Testing Loss: tensor(0.4776)
# Testing Loss: tensor(0.4775)
# Testing Loss: tensor(0.4777)
# Testing Loss: tensor(0.4775)
# Testing Loss: tensor(0.4771)
# Testing Loss: tensor(0.4772)
# Testing Loss: tensor(0.4773)
# Testing Loss: tensor(0.4773)
# Testing Loss: tensor(0.4773)
# Testing Loss: tensor(0.4775)
# Testing Loss: tensor(0.4777)
# Testing Loss: tensor(0.4781)
# Testing Loss: tensor(0.4768)
# Testing Loss: tensor(0.4771)
# Testing Loss: tensor(0.4759)
# Testing Loss: tensor(0.4760)
# Testing Loss: tensor(0.4756)
# Testing Loss: tensor(0.4756)
# Testing Loss: tensor(0.4754)
# Testing Loss: tensor(0.4753)
# Testing Loss: tensor(0.4754)
# Testing Loss: tensor(0.4755)
# Testing Loss: tensor(0.4756)
# Testing Loss: tensor(0.4757)
# Testing Loss: tensor(0.4754)
# Testing Loss: tensor(0.4758)
# Testing Loss: tensor(0.4753)
# Testing Loss: tensor(0.4755)
# Testing Loss: tensor(0.4762)
# Testing Loss: tensor(0.4762)
# Testing Loss: tensor(0.4759)
# Testing Loss: tensor(0.4747)
# Testing Loss: tensor(0.4753)
# Testing Loss: tensor(0.4759)
# Testing Loss: tensor(0.4760)
# Testing Loss: tensor(0.4759)
# Testing Loss: tensor(0.4760)
# Testing Loss: tensor(0.4762)
# Testing Loss: tensor(0.4762)
# Testing Loss: tensor(0.4759)
# Testing Loss: tensor(0.4756)
# Testing Loss: tensor(0.4755)
# Testing Loss: tensor(0.4758)
# Testing Loss: tensor(0.4746)
# Testing Loss: tensor(0.4747)
# Testing Loss: tensor(0.4750)
# Testing Loss: tensor(0.4749)
# Testing Loss: tensor(0.4738)
# Testing Loss: tensor(0.4738)
# Testing Loss: tensor(0.4736)
# Testing Loss: tensor(0.4736)
# Testing Loss: tensor(0.4732)
# Testing Loss: tensor(0.4720)
# Testing Loss: tensor(0.4725)
# Testing Loss: tensor(0.4724)
# Testing Loss: tensor(0.4726)
# Testing Loss: tensor(0.4730)
# Testing Loss: tensor(0.4730)
# Testing Loss: tensor(0.4719)
# Testing Loss: tensor(0.4708)
# Testing Loss: tensor(0.4704)
# Testing Loss: tensor(0.4693)
# Testing Loss: tensor(0.4682)
# Testing Loss: tensor(0.4682)
# Testing Loss: tensor(0.4685)
# Testing Loss: tensor(0.4688)
# Testing Loss: tensor(0.4688)
# Testing Loss: tensor(0.4678)
# Testing Loss: tensor(0.4680)
# Testing Loss: tensor(0.4682)
# Testing Loss: tensor(0.4685)
# Testing Loss: tensor(0.4693)
# Testing Loss: tensor(0.4682)
# Testing Loss: tensor(0.4672)
# Testing Loss: tensor(0.4661)
# Testing Loss: tensor(0.4662)
# Testing Loss: tensor(0.4662)
# Testing Loss: tensor(0.4666)
# Testing Loss: tensor(0.4670)
# Testing Loss: tensor(0.4672)
# Testing Loss: tensor(0.4673)
# Testing Loss: tensor(0.4662)
# Testing Loss: tensor(0.4668)
# Testing Loss: tensor(0.4668)
# Testing Loss: tensor(0.4671)
# Testing Loss: tensor(0.4683)
# Testing Loss: tensor(0.4672)
# Testing Loss: tensor(0.4662)
